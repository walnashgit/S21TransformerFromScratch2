# %% [markdown]
# <a href="https://colab.research.google.com/github/walnashgit/S21TransformerFromScratch2/blob/main/Copy_of_S21TransformerFromScratch2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/walnashgit/S21TransformerFromScratch2.git
# Out:
# Cloning into 'S21TransformerFromScratch2'...
# remote: Enumerating objects: 26, done.
# remote: Counting objects: 100% (26/26), done.
# remote: Compressing objects: 100% (24/24), done.
# remote: Total 26 (delta 12), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (26/26), 437.18 KiB | 7.54 MiB/s, done.
# Resolving deltas: 100% (12/12), done.

# %%
# %cd /content/S21TransformerFromScratch2
# Out:
# /content/S21TransformerFromScratch2

# %%
# !pip install tiktoken
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 8.3 MB/s eta 0:00:00
# ...

# %%
from train import *
# Out:
# using device: cuda
# loaded 338025 tokens
# 1 epoch = 27 batches
# num decayed parameter tensors: 50, with 124,354,560 parameters
# num non-decayed parameter tensors: 98, with 121,344 parameters
# using fused AdamW: True
# /content/S21TransformerFromScratch2/train.py:108: UserWarning: torch.nn.utils.clip_grad_norm is now deprecated in favor of torch.nn.utils.clip_grad_norm_.
#   norm = torch.nn.utils.clip_grad_norm(model.parameters(), 1.0)
# Streaming output truncated to the last 5000 lines.
# step1001 | loss: 3.9384403228759766 | dt: 697.00ms | tok/sec:  17629.75 | norm:  0.99 | lr 0.000564344356440644
# step1002 | loss: 4.1093645095825195 | dt: 695.48ms | tok/sec:  17668.45 | norm:  0.99 | lr 0.0005642739925685093
# step1003 | loss: 4.003232002258301 | dt: 699.59ms | tok/sec:  17564.62 | norm:  1.38 | lr 0.0005642035642542027
# step1004 | loss: 3.948439121246338 | dt: 696.55ms | tok/sec:  17641.20 | norm:  1.34 | lr 0.000564133071517097
# ...

# %%
torch.save(model.state_dict(), "S21_model.pth")

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive
